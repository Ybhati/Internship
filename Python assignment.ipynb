# %% [markdown]
# 11. Write a python program to find the factorial of a number

# %%
i=int(input('enter number : '))
fac=1
while i>0:
    fac=fac*i
    i=i-1
print('Factorial=',fac)
# Out:
# enter number : 9
# Factorial= 362880

# %% [markdown]
# 12. Write a python program to find whether a number is prime or composite

# %%
a=int(input('enter number :'))
count=0
i=1
while i<=a:

    if a%i==0:
        count=count+1
    i=i+1
if count==2:
    print("It's Prime Number")
elif count>2:
    print("It's composite number")
else:
    print("The number is neither Prime nor Composite")
# Out:
# enter number :9
# It's composite number

# %% [markdown]
# 13. Write a python program to check whether a given string is palindrome or not

# %%
a=input("Enter String:")
b=a[-1::-1]
if(a==b):
    print("Palindrome String")
else:
    print("Not Palindrome String")
# Out:
# Enter String:civic
# Palindrome String

# %% [markdown]
# 14. Write a Python program to get the third side of right-angled triangle from two given sides

# %%
from math import sqrt
print('Input length of shorter triangle side : ')
a=float(input("Enter a: "))
b=float(input("Enter b: "))
c=sqrt(a**2 + b**2)
print("Input Length of shorter triangle side ",c)
# Out:
# Input length of shorter triangle side :
# Enter a: 6.3
# Enter b: 9.6
# Input Length of shorter triangle side  11.482595525402782

# %% [markdown]
# 15. Write a python program to print the frequency of each of the characters present in a given string

# %%
str=input('Enter String')
l=list(str)
freq=[l.count(ele)for ele in l]
d=dict(zip(l,freq))
print(d)
# Out:
# Enter StringLife is Beautiful
# {'L': 1, 'i': 3, 'f': 2, 'e': 2, ' ': 2, 's': 1, 'B': 1, 'a': 1, 'u': 2, 't': 1, 'l': 1}
