# %%
import selenium
from selenium import webdriver 
import pandas as pd
from selenium .webdriver.common.by import By
import warnings 
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="f77a1a35-ece1-4b99-a10b-5d4b651d6f9e")>

# %%
search_job.send_keys("Data Analyst")

# %%
search_locn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
search_locn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="c4195cb1-2f9a-4b5d-afc1-5469624d06c1")>

# %%
search_locn.send_keys("Bangalore")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="5e103bd0-2343-46a4-8917-2292ba6c3ae3")>

# %%
search_btn.click()

# %%
title_tags=driver.find_elements(By.XPATH,'(//a[@class="title fw500 ellipsis"])') 
print(len(title_tags))
# Out:
# 20

# %%
job_titles = []
for i in title_tags:
    job_titles.append(i.text)
len(job_titles)
# Out:
# 20

# %%
job_titles
# Out:
# ['Data Analyst I',
#  'Data Science / Data Engineer / Business Analyst / Full Stack Developer',
#  'Sr.Business Data Analyst',
#  'Senior Data Analyst',
#  'Sr Data Analyst',
#  'Data Analyst - IIM/ISB/MDI/FMS/SP Jain',
#  'Data Analyst / Business analyst - US MNC (analytics)',
#  'Business Analyst/Data Analyst',
#  'Junior Data Analyst',
#  'Senior Data Analysis Analyst',
#  'Data Analyst - Python/SQL',
#  'Data Analyst',
#  'Data Analyst - IT',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Master Data Management Business Analyst',
#  'Data Analyst / Data Source Engineer - SOQL/SOSL',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst - R/Tableau']

# %%
company_tags=driver.find_elements(By.XPATH,'(//a[@class="subTitle ellipsis fleft"])') 
print(len(company_tags))
# Out:
# 20

# %%
company_names = []
for i in company_tags:
    company_names.append(i.text)
len(company_names)
# Out:
# 20

# %%
company_names
# Out:
# ['Cerner',
#  'NETWORTH DATA PRODUCTS PRIVATE LIMITED',
#  'Collabera',
#  'Hudsons bay Company (HBC)',
#  'Thomson Reuters',
#  'K12 Techno Services Pvt Ltd',
#  'Aspyra HR Services',
#  'Telamon HR Solutions',
#  'ICF Next',
#  'Capco',
#  'Affine',
#  'Everest Fleet Pvt. Ltd.',
#  'Yespired',
#  'Thomson Reuters',
#  'KrazyBee',
#  'Accenture',
#  'Talent Placers',
#  'RGBSI',
#  'Botree Software',
#  'Jobs Accuracy']

# %%
loc_tags=driver.find_elements(By.XPATH,'(//li[@class="fleft grey-text br2 placeHolderLi location"])') 
print(len(loc_tags))
# Out:
# 20

# %%
Location = []
for i in loc_tags:
    Location.append(i.text)
len(Location)
# Out:
# 20

# %%
Location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, karnataka\n(WFH during Covid)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Gurgaon/Gurugram, Delhi / NCR\n(WFH during Covid)',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Delhi / NCR',
#  'Bangalore/Bengaluru, New Delhi',
#  'Bangalore/Bengaluru, Pune, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Kolkata, Thane, Hyderabad/Secunderabad, Delhi / NCR',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(Old Madras Road)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
exp_tags=driver.find_elements(By.XPATH,'(//li[@class="fleft grey-text br2 placeHolderLi experience"])') 
print(len(exp_tags))
# Out:
# 20

# %%
experience = []
for i in exp_tags:
    experience.append(i.text)
len(experience)
# Out:
# 20

# %%
jobs=pd.DataFrame()
jobs['job-title']=job_titles
jobs['Location']=Location
jobs['company_name']=company_names
jobs['experience_required']=experience
jobs[0:10]
# Out:
#                                            job-title  \
# 0                                     Data Analyst I
# 1  Data Science / Data Engineer / Business Analys...
# 2                           Sr.Business Data Analyst
# 3                                Senior Data Analyst
# 4                                    Sr Data Analyst
# 5             Data Analyst - IIM/ISB/MDI/FMS/SP Jain
# 6  Data Analyst / Business analyst - US MNC (anal...
# 7                      Business Analyst/Data Analyst
# 8                                Junior Data Analyst
# 9                       Senior Data Analysis Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, karnataka\n(WFH during Co...
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Q2

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="4b8f2b37-9913-4be4-b6be-95c0c4e4f676")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_locn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
search_locn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="71b57e8c-32e9-4f6f-aeaa-446235b5186d")>

# %%
search_locn.send_keys("Bangalore")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="0ef254f9-6807-43c9-9510-1a81350efa4e")>

# %%
search_btn.click()

# %%
title_tags=driver.find_elements(By.XPATH,'(//a[@class="title fw500 ellipsis"])')

# %%
job_titles = []
for i in title_tags:
    job_titles.append(i.text)
len(job_titles)
# Out:
# 20

# %%
job_titles
# Out:
# ['Urgent Job Opening For AI Practitioner - Data Science at Wipro Holmes',
#  'Hiring For Senior Data Scientist',
#  'Senior Data Scientist',
#  'Dataiku Consultant',
#  'Research and Development -AI/ML -(PhD )',
#  'Opportunity For Data Scientist - Female Candidates ONLY',
#  'Senior Data Science Engineer',
#  'Data Science - Engineering Manager',
#  'Data Scientist',
#  'Data & Analytics Tech - Informatica Cloud- Senior Associate',
#  'Data Scientist: Advanced Analytics',
#  'Research Scientist',
#  'Principal - Data Scientist',
#  'Data Scientist- Assistant Manager/Manager',
#  'EY GBS - Assistant Director - Data Science (10+ years), Bangalore',
#  'Data Scientist',
#  'Data Scientist, Personalization',
#  'AWS Sagemaker',
#  'Data Scientist',
#  'Data Scientist: Artificial Intelligence']

# %%
loc_tags=driver.find_elements(By.XPATH,'(//li[@class="fleft grey-text br2 placeHolderLi location"])')

# %%
Location = []
for i in loc_tags:
    Location.append(i.text)
len(Location)
# Out:
# 20

# %%
Location
# Out:
# ['Bangalore/Bengaluru, Kochi/Cochin, New Delhi, Coimbatore, Chennai, Pune, Mumbai, Hyderabad',
#  'Bangalore/Bengaluru, Pune',
#  'Bangalore/Bengaluru, Mumbai, Hyderabad/Secunderabad, Pune, REMOTE',
#  'Bangalore/Bengaluru, Pune, Chennai',
#  'Bangalore/Bengaluru, Noida, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Delhi / NCR',
#  'Bangalore/Bengaluru, Gurgaon/Gurugram, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Gurgaon/Gurugram, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Noida, Mumbai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru\n(WFH during Covid)',
#  'Bangalore/Bengaluru\n(WFH during Covid)',
#  'Bangalore/Bengaluru']

# %%
company_tags=driver.find_elements(By.XPATH,'(//a[@class="subTitle ellipsis fleft"])')

# %%
company_names = []
for i in company_tags:
    company_names.append(i.text)
len(company_names)
# Out:
# 20

# %%
company_names
# Out:
# ['Wipro',
#  'TATA CONSULTANCY SERVICES (TCS)',
#  'Spiceworks',
#  'Wipro',
#  'EXL',
#  'PayU',
#  'Fractal Analytics',
#  'Paytm',
#  'Applied Materials',
#  'PwC',
#  'IBM',
#  'IBM',
#  'Schneider Electric',
#  'Genpact',
#  'EYGBS',
#  'IBM',
#  'Walmart',
#  'Wipro',
#  'Wipro',
#  'IBM']

# %%
jobs=pd.DataFrame()
jobs[' job-title']=job_titles
jobs['company_name']=company_names
jobs['job-location']=Location
jobs[0:10]
# Out:
#                                            job-title  \
# 0  Urgent Job Opening For AI Practitioner - Data ...
# 1                   Hiring For Senior Data Scientist
# 2                              Senior Data Scientist
# 3                                 Dataiku Consultant
# 4            Research and Development -AI/ML -(PhD )
# 5  Opportunity For Data Scientist - Female Candid...
# 6                       Senior Data Science Engineer
# 7                 Data Science - Engineering Manager
# 8                                     Data Scientist
# 9  Data & Analytics Tech - Informatica Cloud- Sen...
#
#                       company_name  \
# 0                            Wipro
# 1  TATA CONSULTANCY SERVICES (TCS)
# 2                       Spiceworks
# 3                            Wipro
# 4                              EXL
# 5                             PayU
# 6                Fractal Analytics
# 7                            Paytm
# 8                Applied Materials
# ...

# %% [markdown]
# # SEL Q3

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME,"suggestor-input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="0d884d11-6c03-4229-a774-3dfdba5766d2")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_locn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
search_locn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="758e5d03-4803-4161-86bc-45e790567456")>

# %%
search_locn.send_keys("Delhi/NCR")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="06e35e12-5ad6-4b0b-a53f-50245d04943e")>

# %%
search_btn.click()

# %%
salary_check = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]")
salary_check
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="2bff4ce5-1345-4874-b507-9634a79bda33")>

# %%
salary_check.click()

# %%
search_locn=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[13]/div[2]/div[3]/label/p/span[1]")
search_locn.click()

# %%
title_tags=driver.find_elements(By.XPATH,'(//a[@class="title fw500 ellipsis"])') 
print(len(title_tags))
# Out:
# 20

# %%
job_titles = []
for i in title_tags:
    job_titles.append(i.text)
len(job_titles)
# Out:
# 20

# %%
job_titles
# Out:
# ['DigitalBCG GAMMA Data Scientist',
#  'Data Scientist - Noida/Bangalore',
#  'Senior Associate - Data Science',
#  'Data Scientist For Healthcare Product team',
#  'Data Scientist For Healthcare Product team',
#  'Data Scientist - MIND Infotech',
#  'Data Science Associate',
#  'Data Scientist - Engine Algorithm',
#  'Knowledge/Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Seniors',
#  'Data Science',
#  'Data Science',
#  'Data Scientist',
#  'Hiring || Data Scientist || North Delhi || 5.5 days working',
#  'Data scientist- Python',
#  'Dot Net Developer',
#  'Data Engineer']

# %%
loc_tags=driver.find_elements(By.XPATH,'(//li[@class="fleft grey-text br2 placeHolderLi location"])') 
print(len(loc_tags))
# Out:
# 20

# %%
Location = []
for i in loc_tags:
    Location.append(i.text)
len(Location)
# Out:
# 20

# %%
Location
# Out:
# ['New Delhi, Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Mumbai, Hyderabad/Secunderabad, Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Delhi / NCR, Chennai, Bangalore/Bengaluru',
#  'Delhi / NCR, Chennai, Bangalore/Bengaluru',
#  'Noida',
#  'Delhi / NCR(Vaishali)',
#  'Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secunderabad, Lucknow, Chennai, Ahmedabad, Bangalore/Bengaluru',
#  'Delhi / NCR',
#  'Delhi / NCR, Pune, Bangalore/Bengaluru',
#  'Delhi / NCR, Pune, Bangalore/Bengaluru',
#  'Delhi / NCR, Bangalore/Bengaluru, Mumbai (All Areas)\n(WFH during Covid)',
#  'Hyderabad/Secunderabad, New Delhi',
#  'Delhi / NCR, Noida, Faridabad, Gurgaon/Gurugram, Bangalore/Bengaluru, Greater Noida',
#  'Delhi / NCR, Noida, Faridabad, Gurgaon/Gurugram, Bangalore/Bengaluru, Greater Noida',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR(Netaji Subhash Place)',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR, Gurgaon/Gurugram',
#  'Mumbai, New Delhi, Pune']

# %%
company_tags=driver.find_elements(By.XPATH,'(//a[@class="subTitle ellipsis fleft"])') 
print(len(company_tags))
# Out:
# 20

# %%
company_names = []
for i in company_tags:
    company_names.append(i.text)
len(company_names)
# Out:
# 20

# %%
company_names
# Out:
# ['Boston Consulting Group',
#  'EXL',
#  'Black Turtle',
#  'SECUREKLOUD TECHNOLOGIES',
#  'SECUREKLOUD TECHNOLOGIES',
#  'MOTHERSONSUMI INFOTECH & DESIGNS LIMITED',
#  'Kreate Energy',
#  'Primo Hiring',
#  'BOLD Technology Systems',
#  'Mount Talent Consulting Private Limited',
#  'Mount Talent Consulting Private Limited',
#  'Sydata Consulting India Pvt Ltd',
#  'Walking Tree Consultancy Services pvt Ltd',
#  'Mount Talent Consulting Private Limited',
#  'Mount Talent Consulting Private Limited',
#  'Kellton Tech Solutions',
#  'Shriram Automall',
#  'TeamPlus Staffing Solution Pvt Ltd',
#  'Nibha Infotech Private Limited',
#  'excellence']

# %%
exp_tags=driver.find_elements(By.XPATH,'(//li[@class="fleft grey-text br2 placeHolderLi experience"])') 
print(len(exp_tags))
# Out:
# 20

# %%
experience = []
for i in exp_tags:
    experience.append(i.text)
len(experience)
# Out:
# 20

# %%
experience
# Out:
# ['2-5 Yrs',
#  '5-10 Yrs',
#  '4-7 Yrs',
#  '2-7 Yrs',
#  '2-7 Yrs',
#  '4-8 Yrs',
#  '2-4 Yrs',
#  '1-3 Yrs',
#  '3-6 Yrs',
#  '2-4 Yrs',
#  '2-4 Yrs',
#  '3-8 Yrs',
#  '2-5 Yrs',
#  '2-5 Yrs',
#  '2-5 Yrs',
#  '3-6 Yrs',
#  '4-9 Yrs',
#  '3-6 Yrs',
#  '3-8 Yrs',
#  '4-9 Yrs']

# %%
jobs=pd.DataFrame()
jobs['job-title']=job_titles
jobs['job-location']=Location
jobs['company name']=company_names
jobs['experience required']=experience
jobs[1:10]
# Out:
#                                     job-title  \
# 1            Data Scientist - Noida/Bangalore
# 2             Senior Associate - Data Science
# 3  Data Scientist For Healthcare Product team
# 4  Data Scientist For Healthcare Product team
# 5              Data Scientist - MIND Infotech
# 6                      Data Science Associate
# 7           Data Scientist - Engine Algorithm
# 8                    Knowledge/Data Scientist
# 9                              Data Scientist
#
#                                         job-location  \
# 1                         Noida, Bangalore/Bengaluru
# 2  Mumbai, Hyderabad/Secunderabad, Gurgaon/Gurugr...
# 3          Delhi / NCR, Chennai, Bangalore/Bengaluru
# 4          Delhi / NCR, Chennai, Bangalore/Bengaluru
# 5                                              Noida
# 6                              Delhi / NCR(Vaishali)
# 7  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 8                                        Delhi / NCR
# ...

# %% [markdown]
# # SEL Q4

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search = driver.find_element(By.CLASS_NAME,"_3704LK")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="f0f4273f-2bbf-454a-a3db-a056c49bcb84")>

# %%
search.send_keys("sunglasses")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="865da954-4859-4dd9-bf9f-c8139949ab3f")>

# %%
search_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])')    #_2WkVRV
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
Brand
# Out:
# ['ROZZETTA CRAFT',
#  'VINCENT CHASE',
#  'DAHAAZIL',
#  'New Specs',
#  'PIRASO',
#  'Fastrack',
#  'PIRASO',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'PIRASO',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'SRPM',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'ROYAL SON',
#  'NuVew',
#  'PIRASO',
#  'Lee Topper',
#  'GANSTA',
#  'Lee Topper',
#  'CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'HAMIW COLLECTION',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'CRYSTAL CART',
#  'kingsunglasses',
#  'Lee Topper',
#  'AISLIN',
#  'Sewell',
#  'Fastrack',
#  'Fastrack',
#  'ROYAL SON']

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa"])') 
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
Product_Description
# Out:
# ['UV Protection, Gradient Round Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (52)',
#  'UV Protection, Night Vision, Riding Glasses Wayfarer, W...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'Polarized Retro Square Sunglasses (61)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection, Polarized Wayfarer Sunglasses (54)',
#  'UV Protection Sports Sunglasses (62)',
#  'UV Protection Wayfarer Sunglasses (32)',
#  'UV Protection Cat-eye Sunglasses (Free Size)',
# ...

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
price
# Out:
# ['₹379',
#  '₹649',
#  '₹177',
#  '₹264',
#  '₹249',
#  '₹639',
#  '₹359',
#  '₹379',
#  '₹719',
#  '₹249',
#  '₹474',
#  '₹699',
#  '₹211',
#  '₹246',
#  '₹195',
#  '₹759',
#  '₹291',
#  '₹226',
#  '₹229',
#  '₹314',
#  '₹299',
#  '₹189',
#  '₹331',
#  '₹759',
#  '₹303',
#  '₹199',
#  '₹259',
#  '₹899',
#  '₹719',
#  '₹809',
#  '₹379',
#  '₹569',
#  '₹529',
#  '₹214',
#  '₹245',
#  '₹995',
#  '₹265',
#  '₹799',
#  '₹719',
#  '₹711']

# %%
next_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span")
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="f157326c-0f30-49c2-9c93-82533fe9ca2f")>

# %%
next_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])') 
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
Brand
# Out:
# ['kingsunglasses',
#  'PIRASO',
#  'VINCENT CHASE',
#  'AISLIN',
#  'DEIXELS',
#  'Hamiw',
#  'Fastrack',
#  'ROYAL SON',
#  'Fastrack',
#  'kingsunglasses',
#  'kingsunglasses',
#  'IZAAN MART',
#  'Elligator',
#  'New Specs',
#  'AISLIN',
#  'Arnette',
#  'ROYAL SON',
#  'PIRASO',
#  'PIRASO',
#  'GANSTA',
#  'SHAAH COLLECTIONS',
#  'AISLIN',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'AISLIN',
#  'LIZA ANGEL',
#  'Fastrack',
#  'Fastrack',
#  'ROYAL SON',
#  'PHENOMENAL',
#  'Fastrack',
#  'AISLIN',
#  'DEIXELS',
#  'Singco India',
#  'kingsunglasses',
#  'Urbanic',
#  'IZAAN MART']

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa"])') 
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
Product_Description
# Out:
# ['UV Protection Rectangular Sunglasses (55)',
#  'UV Protection Retro Square Sunglasses (52)',
#  'by Lenskart Polarized, UV Protection Wayfarer Sunglasse...',
#  'Toughened Glass Lens, UV Protection Aviator, Wayfarer S...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Riding Glasses Round Sunglasses (Free Si...',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Retro Square Sunglasses (55)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Mirrored Aviator Sunglasses (Free Size)',
#  'UV Protection, Riding Glasses, Mirrored Wayfarer Sungla...',
#  'Mirrored, Gradient Cat-eye Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (53)',
#  'Mirrored, UV Protection, Riding Glasses, Others Round S...',
#  'UV Protection, Gradient Oval Sunglasses (58)',
#  'Others Oval Sunglasses (53)',
#  'Mirrored Aviator Sunglasses (55)',
#  'UV Protection Over-sized Sunglasses (65)',
# ...

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
price
# Out:
# ['₹189',
#  '₹306',
#  '₹749',
#  '₹975',
#  '₹224',
#  '₹239',
#  '₹1,039',
#  '₹616',
#  '₹639',
#  '₹269',
#  '₹213',
#  '₹197',
#  '₹207',
#  '₹299',
#  '₹498',
#  '₹3,199',
#  '₹379',
#  '₹419',
#  '₹246',
#  '₹314',
#  '₹324',
#  '₹498',
#  '₹474',
#  '₹1,234',
#  '₹214',
#  '₹426',
#  '₹279',
#  '₹498',
#  '₹179',
#  '₹809',
#  '₹639',
#  '₹699',
#  '₹341',
#  '₹719',
#  '₹498',
#  '₹217',
#  '₹598',
#  '₹329',
#  '₹719',
#  '₹530']

# %%
next_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span")
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="f157326c-0f30-49c2-9c93-82533fe9ca2f")>

# %%
next_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])') 
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
Brand
# Out:
# ['SUNBEE',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'NuVew',
#  'ROYAL SON',
#  'Silver Kartz',
#  'hipe',
#  'AISLIN',
#  'HAMIW COLLECTION',
#  'ROYAL SON',
#  'SRPM',
#  'ROYAL SON',
#  'New Specs',
#  'Fastrack',
#  'Fastrack',
#  'ROYAL SON',
#  'VINCENT CHASE',
#  'ROYAL SON',
#  'Mi',
#  'ROYAL SON',
#  'Fastrack',
#  'kingsunglasses',
#  'VINCENT CHASE',
#  'AISLIN',
#  'Fastrack',
#  'Singco India',
#  'Fastrack',
#  'ROYAL SON',
#  'Fastrack',
#  'VINCENT CHASE',
#  'PHENOMENAL',
#  'NuVew',
#  'Fastrack',
#  'Elligator',
#  'GANSTA',
#  'VINCENT CHASE',
#  'Fastrack',
#  'kingsunglasses',
#  'Roadster',
#  'VINCENT CHASE']

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa"])') 
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
Product_Description
# Out:
# ['UV Protection, Polarized, Mirrored Wayfarer Sunglasses ...',
#  'UV Protection, Gradient Round Sunglasses (Free Size)',
#  'Night Vision, UV Protection Round Sunglasses (54)',
#  'UV Protection Cat-eye Sunglasses (60)',
#  'UV Protection, Gradient Butterfly Sunglasses (62)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'Mirrored, Gradient, Riding Glasses Round Sunglasses (55...',
#  'UV Protection, Gradient Cat-eye, Oval Sunglasses (61)',
#  'UV Protection Wayfarer, Sports, Shield, Rectangular, Re...',
#  'Mirrored Aviator Sunglasses (58)',
#  'UV Protection Wayfarer Sunglasses (53)',
#  'Polarized, UV Protection Wrap-around Sunglasses (62)',
#  'UV Protection Round Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (57)',
#  'Polarized, UV Protection Wrap-around Sunglasses (62)',
#  'Polarized, UV Protection Round Sunglasses (50)',
#  'UV Protection Rectangular, Retro Square Sunglasses (58)',
# ...

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
price
# Out:
# ['₹283',
#  '₹379',
#  '₹233',
#  '₹385',
#  '₹699',
#  '₹288',
#  '₹210',
#  '₹498',
#  '₹219',
#  '₹379',
#  '₹235',
#  '₹799',
#  '₹268',
#  '₹729',
#  '₹639',
#  '₹759',
#  '₹849',
#  '₹474',
#  '₹1,009',
#  '₹711',
#  '₹849',
#  '₹299',
#  '₹949',
#  '₹498',
#  '₹809',
#  '₹664',
#  '₹639',
#  '₹569',
#  '₹721',
#  '₹849',
#  '₹369',
#  '₹198',
#  '₹949',
#  '₹329',
#  '₹314',
#  '₹749',
#  '₹639',
#  '₹299',
#  '₹649',
#  '₹749']

# %%
sunglasses=pd.DataFrame()
sunglasses['Brand']=Brand+Brand+Brand
sunglasses['Product_Description']=Product_Description+Product_Description+Product_Description
sunglasses['price']=price+price+price
sunglasses[0:100]
# Out:
#              Brand                                Product_Description   price
# 0           SUNBEE  UV Protection, Polarized, Mirrored Wayfarer Su...    ₹283
# 1   ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...    ₹379
# 2             SRPM  Night Vision, UV Protection Round Sunglasses (54)    ₹233
# 3            NuVew              UV Protection Cat-eye Sunglasses (60)    ₹385
# 4        ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (62)    ₹699
# ..             ...                                                ...     ...
# 95       ROYAL SON  Polarized, UV Protection Wrap-around Sunglasse...    ₹759
# 96   VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹849
# 97       ROYAL SON  UV Protection Rectangular, Retro Square Sungla...    ₹474
# 98              Mi           Polarized Aviator Sunglasses (Free Size)  ₹1,009
# 99       ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)    ₹711
#
# [100 rows x 3 columns]

# %% [markdown]
# # SEL Q5

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART")

# %%
import time

# %%
urls=[]
short_review=[]
complete_review=[]
stars=[]
time.sleep(2)

# %%
#scraping 10 pages url
url_1 = driver.find_elements(By.XPATH,"//a[@class='ge-49M _2Kfbh8']")
for i in url_1:
    urls.append(i.get_attribute('href'))
url_2 = driver.find_elements(By.XPATH,"//a[@class='ge-49M']")
for i in url_2:
    urls.append(i.get_attribute('href'))
time.sleep(4)


for i in urls:
    driver.get(i)
    #for scrapping the number of stars
    for j in driver.find_elements(By.XPATH,"//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        stars.append(j.text)
    #for scrapping the short review
    for k in driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']"):
        short_review.append(k.text)
    #for scrapping the complete review
    for l in driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']/div/div"):
        complete_review.append(l.text)

# %%
print(len(stars),len(short_review),len(complete_review))
# Out:
# 100 100 100

# %%
Phone=pd.DataFrame()
Phone['Rating']=stars
Phone['short_review']=short_review
Phone['complete_review']=complete_review
Phone
# Out:
#    Rating         short_review  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       5   Highly recommended
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5               Super!
# 96      5            Wonderful
# 97      5    Worth every penny
# 98      5  Best in the market!
# 99      5            Fabulous!
#
#                                       complete_review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   What a camera .....just awesome ..you can feel...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  This is my first ever iPhone.\nAnd I truly don...
# 96  Nice value for money good and best price I pho...
# 97  Undoubtedly Iphone 11 is the most successful m...
# ...

# %% [markdown]
# # SEL Q6

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="df47be12-fc4e-437a-bb99-96c7aab509f6")>

# %%
search.send_keys("sneakers")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="0ee3f090-baa0-45b6-b3de-7675a9042721")>

# %%
search_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])')    
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"])')   #IRpwTa _2-ICcC
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
next_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="137dda23-eea3-4b4c-b0bb-d9fd47dd4370")>

# %%
next_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])')    
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"])')   #IRpwTa _2-ICcC
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
next_btn=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="922885e9dea22e46b0bec6d499e9d965", element="f773c5e4-4a27-45d6-a6e2-ded5535aaa04")>

# %%
next_btn.click()

# %%
Brand_tags=driver.find_elements(By.XPATH,'(//div[@class="_2WkVRV"])')    
print(len(Brand_tags))
# Out:
# 40

# %%
Brand = []
for i in Brand_tags:
    Brand.append(i.text)
len(Brand)
# Out:
# 40

# %%
price_tags=driver.find_elements(By.XPATH,'(//div[@class="_30jeq3"])') 
print(len(price_tags))
# Out:
# 40

# %%
price = []
for i in price_tags:
    price.append(i.text)
len(price)
# Out:
# 40

# %%
product_tags=driver.find_elements(By.XPATH,'(//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"])')   #IRpwTa _2-ICcC
print(len(product_tags))
# Out:
# 40

# %%
Product_Description = []
for i in product_tags:
    Product_Description.append(i.text)
len(Product_Description)
# Out:
# 40

# %%
Sneakers=pd.DataFrame()
Sneakers['Brand']=Brand+Brand+Brand
Sneakers['Product_Description']=Product_Description+Product_Description+Product_Description
Sneakers['price']=price+price+price
Sneakers[0:100]
# Out:
#                     Brand                                Product_Description  \
# 0   HRX by Hrithik Roshan                                   Sneakers For Men
# 1                    PUMA                    Suede Classic+ Sneakers For Men
# 2               TrendWalk  Original Luxury Branded Fashionable Men's Casu...
# 3                 Nilatin                                   Sneakers For Men
# 4                PREKANZO              New Stylish Casual Sneakers For Women
# ..                    ...                                                ...
# 95               KWIK FIT  Casual Trendy Fashion Sport Sneaker Shoes Gym ...
# 96                   PUMA            BMW MMS Electron E Pro Sneakers For Men
# 97                  SPARX                                   Sneakers For Men
# 98                   Hida                                   Sneakers For Men
# 99         LOUIS PHILIPPE                                   Sneakers For Men
#
#      price
# 0   ₹1,359
# 1   ₹2,799
# ...

# %% [markdown]
# # SEL Q7
# was not able to scrap

# %% [markdown]
# # SEL Q8

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="3ec2baa4-4348-4210-821f-126e8de4667f")>

# %%
search.send_keys("Laptop")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="877bb9c2-b3e5-47a1-b707-71e0fcde56ab")>

# %%
search_btn.click()

# %%
CPU_Type = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[14]/span/a/span")
CPU_Type
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="b0b9ada1-1154-4a63-97d8-4085696e7014")>

# %%
CPU_Type.click()

# %%
Title_tags=driver.find_elements(By.XPATH,'(//div[@class="a-section a-spacing-none s-padding-right-small s-title-instructions-style"])')    
print(len(Title_tags))
# Out:
# 16

# %%
Title = []
for i in Title_tags:
    Title.append(i.text)
len(Title)
# Out:
# 16

# %%
Title[0:10]
# Out:
# ['Acer Predator Helios 500 Gaming Laptop (11Th Gen Intel Core I9/17.3 Inches 4K Uhd Display/64Gb Ddr4 Ram/2Tb Ssd/1Tb HDD/RTX 3080 Graphics/Windows 10 Home/Per Key RGB Backlit Keyboard) Ph517-52',
#  'Asus Rog Strix Scar 15 (2022) 15.6 Inches 2K Wqhd 240Hz/3Ms Intel Core I9-12900H 12Th Gen Rtx 3070 Ti 8Gb Graphics, Gaming Laptop (32Gb/1Tb Ssd/Windows 11 Home/Office 2021/Black/2.3 Kg) G533Zw-Ln136Ws',
#  'Acer Predator Helios 300 11Th Gen Intel Core I9-11900H 15.6 Inches (39.62Cms) Fhd Ips Gaming Laptop (16 Gb/1Tb Ssd/Windows 11 Home/6 Gb Graphics/Nvidia Geforce Rtx 3060/360 Hz, Black, 2.3 Kg) Ph315-54',
#  'Hp Envy 15- 11Th Gen Intel Core I9/32Gb/1Tb Ssd/15.6 Inches 400 Nits,4K Amoled Touch, Tuv + Windows 11 Pro 64/Nvidia Geforce RTX 3060 6Gb Graphics/Alexa/Fpr /B&O/2.14Kg,15-Ep1087Tx, Natural Silver',
# ...

# %%
price_tags=driver.find_elements(By.XPATH,'(//span[@class="a-price-whole"])')    
print(len(price_tags))
# Out:
# 15

# %%
Price = []
for i in price_tags:
    Price.append(i.text)
len(Price)
# Out:
# 15

# %%
Price[0:10]
# Out:
# ['3,79,990',
#  '2,36,494',
#  '1,44,990',
#  '2,02,617',
#  '1,81,990',
#  '2,75,500',
#  '3,23,741',
#  '1,91,990',
#  '3,21,990',
#  '3,57,690']

# %% [markdown]
# # SEL Q 9

# %%
url='https://www.ambitionbox.com/'
driver.get(url)

# %%
jobs_btn=driver.find_element(By.XPATH,"/html/body/div[1]/nav/nav/a[6]")
jobs_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="8bdcc68b-6dae-468f-95be-102ebce30bc9")>

# %%
jobs_btn.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="1ca4a9eb-aa2a-43f7-b622-4dd48c49b07c")>

# %%
search.send_keys("Data Scientist")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="e4931090-98c5-46c3-9dc6-7ec5c3f72d11")>

# %%
search_btn.click()

# %%
Loc_btn=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[5]/div/label")
Loc_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="898a596a-aba6-46e6-bec1-d271af5ead46")>

# %%
Loca_btn=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[5]/div/label")

# %%
Comapany_tags=driver.find_elements(By.XPATH,'(//div[@class="company-info"])')    
print(len(Comapany_tags))
# Out:
# 11

# %%
Company = []
for i in Comapany_tags:
    Company.append(i.text)
len(Company)
# Out:
# 11

# %%
Company
# Out:
# ['Amazon\n · \n4.2\nbased on 14.9k Reviews',
#  'Amazon\n4.2\n(14.9k Reviews)',
#  'J.P. Morgan Services India Private Limited\n4.2\n(3.3k Reviews)',
#  'CATERPILLAR INDIA PRIVATE LTD\n4.2\n(806 Reviews)',
#  'CATERPILLAR INDIA PRIVATE LTD\n4.2\n(806 Reviews)',
#  'IBM India Pvt. Limited\n4.2\n(14.7k Reviews)',
#  'Shell India Markets Private Limited\n4.4\n(1.1k Reviews)',
#  'IBM India Pvt. Limited\n4.2\n(14.7k Reviews)',
#  'Schneider Electric India Pvt. Ltd.\n4.2\n(3.7k Reviews)',
#  'IBM India Pvt. Limited\n4.2\n(14.7k Reviews)',
#  'IBM India Pvt. Limited\n4.2\n(14.7k Reviews)']

# %%
Posting_tags=driver.find_elements(By.XPATH,'(//span[@class="body-small-l"])')    
print(len(Posting_tags))
# Out:
# 20

# %%
Posting = []
for i in Posting_tags:
    Posting.append(i.text)
len(Posting)
# Out:
# 20

# %%
Posting
# Out:
# ['2d ago',
#  'via iimjobs.com',
#  '2d ago',
#  'via naukri.com',
#  '1d ago',
#  'via naukri.com',
#  '1d ago',
#  'via naukri.com',
#  '4d ago',
#  'via naukri.com',
#  '2d ago',
#  'via naukri.com',
#  '5d ago',
#  'via naukri.com',
#  '5d ago',
#  'via naukri.com',
#  '5d ago',
#  'via naukri.com',
#  '5d ago',
#  'via naukri.com']

# %% [markdown]
# # SEL Q10

# %%
url='https://www.ambitionbox.com/'
driver.get(url)

# %%
salery_btn=driver.find_element(By.XPATH,"/html/body/div[1]/nav/nav/a[4]")
salery_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="bea8c8c7-c235-4624-9e7b-67d83ec7dfc8")>

# %%
salery_btn.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div/div/div/div[1]/span/input")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="43da7621-02a3-4be9-a6d8-b339c58908fd")>

# %%
search.send_keys("Data Scientist")

# %%
search_btn=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div/div/div/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="9b5c5b86-0c6b-4b7a-a5a7-f38d28e54d28")>

# %%
search_btn.click()

# %%
Job_btn=driver.find_element(By.XPATH,"/html/body/section[1]/div/section/div/div/div/div/div/div/div[5]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a")
Job_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60245dbdc7a51c40bf85a7ea44ab57ad", element="b320bd39-b447-4225-bb35-f61bb568b147")>

# %%
Job_btn.click()
